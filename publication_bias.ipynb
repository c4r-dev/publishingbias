# %% [markdown]
# # Intuition for Publication Bias
#
# This notebook provides an interactive HTML visualization demonstrating the concept of publication bias.
#
# Adjust the slider in the embedded HTML to explore how the proportion of unpublished null results affects the observed outcomes.

# %%
from IPython.display import IFrame
IFrame(src='./publication_bias.html', width='100%', height='600px')
